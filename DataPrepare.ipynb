# %% [markdown]
# ## 데이터 병합

# %% [markdown]
# ### 데이터베이스 스타일 DataFrame 병합

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np

# %%
df1 = DataFrame({'key': ['b','b','a','c','a','a','b'],
                'data1': range(7)})
df1
# Out:
#    data1 key
# 0      0   b
# 1      1   b
# 2      2   a
# 3      3   c
# 4      4   a
# 5      5   a
# 6      6   b

# %%
df2 = DataFrame({'key': ['a','b','d'],
                'data2': range(3)})
df2
# Out:
#    data2 key
# 0      0   a
# 1      1   b
# 2      2   d

# %%
pd.merge(df1, df2)
# Out:
#    data1 key  data2
# 0      0   b      1
# 1      1   b      1
# 2      6   b      1
# 3      2   a      0
# 4      4   a      0
# 5      5   a      0

# %% [markdown]
# # 파이썬 코드 숨길 수 없나?
#
#  - 코어모듈을 c로 작성하고 파이썬으로 컴파일해서, interface만 사용하거나
#  - web servicec로 만들거나...
#
#  --> 그렇지 않으면, 파이썬 코드는 노출을 방지할 수 없다.

# %% [markdown]
# ## 축따라 이어붙이기

# %% [markdown]
# ## 마지막 강의 : 받아쓰기 ㅋㅋ
#
# #### JSON   파일을 읽어들어 db 객체 만들기

# %%
import json
db = json.load(open('pydata-book/ch07/foods-2011-10-03.json'))
len(db)
# Out:
# 6636

# %%
db[0].keys()
# Out:
# [u'portions',
#  u'description',
#  u'tags',
#  u'nutrients',
#  u'group',
#  u'id',
#  u'manufacturer']

# %%
db[0]['nutrients'][0]
# Out:
# {u'description': u'Protein',
#  u'group': u'Composition',
#  u'units': u'g',
#  u'value': 25.18}

# %%
nutrients = DataFrame(db[0]['nutrients'])
nutrients[:7]
# Out:
#                    description        group units    value
# 0                      Protein  Composition     g    25.18
# 1            Total lipid (fat)  Composition     g    29.20
# 2  Carbohydrate, by difference  Composition     g     3.06
# 3                          Ash        Other     g     3.28
# 4                       Energy       Energy  kcal   376.00
# 5                        Water  Composition     g    39.28
# 6                       Energy       Energy    kJ  1573.00

# %%
info_keys = ['description', 'group', 'id', 'manufacturer']
info = DataFrame(db, columns=info_keys)

# %%
info[:5]
# Out:
#                           description                   group    id  \
# 0                     Cheese, caraway  Dairy and Egg Products  1008
# 1                     Cheese, cheddar  Dairy and Egg Products  1009
# 2                        Cheese, edam  Dairy and Egg Products  1018
# 3                        Cheese, feta  Dairy and Egg Products  1019
# 4  Cheese, mozzarella, part skim milk  Dairy and Egg Products  1028
#
#   manufacturer
# 0
# 1
# 2
# 3
# 4

# %%
info[-5:]
# Out:
#                                             description  \
# 6631                             Bologna, beef, low fat
# 6632  Turkey and pork sausage, fresh, bulk, patty or...
# 6633                              Babyfood, juice, pear
# 6634         Babyfood, dessert, banana yogurt, strained
# 6635              Babyfood, banana no tapioca, strained
#
#                             group     id manufacturer
# 6631  Sausages and Luncheon Meats  42161
# 6632  Sausages and Luncheon Meats  42173
# 6633                   Baby Foods  43408         None
# 6634                   Baby Foods  43539         None
# 6635                   Baby Foods  43546         None

# %% [markdown]
# 음식 분류별 개수 통개 산출

# %%
pd.value_counts(info.group)[:10]
# Out:
# Vegetables and Vegetable Products    812
# Beef Products                        618
# Baked Products                       496
# Breakfast Cereals                    403
# Legumes and Legume Products          365
# Fast Foods                           365
# Lamb, Veal, and Game Products        345
# Sweets                               341
# Fruits and Fruit Juices              328
# Pork Products                        328
# dtype: int64

# %% [markdown]
# ####

# %%
nutrients = []

for rec in db:
    fnuts = DataFrame(rec['nutrients'])
    fnuts['id'] = rec['id']
    nutrients.append(fnuts)
    
nutrients = pd.concat(nutrients, ignore_index=True)

# %%
nutrients
# Out:
#                                description        group    units     value  \
# 0                                  Protein  Composition        g    25.180
# 1                        Total lipid (fat)  Composition        g    29.200
# 2              Carbohydrate, by difference  Composition        g     3.060
# 3                                      Ash        Other        g     3.280
# 4                                   Energy       Energy     kcal   376.000
# 5                                    Water  Composition        g    39.280
# 6                                   Energy       Energy       kJ  1573.000
# 7                     Fiber, total dietary  Composition        g     0.000
# 8                              Calcium, Ca     Elements       mg   673.000
# 9                                 Iron, Fe     Elements       mg     0.640
# 10                           Magnesium, Mg     Elements       mg    22.000
# ...

# %% [markdown]
# #### 중복데이터가 많음

# %%
nutrients.duplicated().sum()
# Out:
# 14179

# %% [markdown]
# #### 중복제거

# %%
nutrients = nutrients.drop_duplicates()
nutrients
# Out:
#                                description        group    units     value  \
# 0                                  Protein  Composition        g    25.180
# 1                        Total lipid (fat)  Composition        g    29.200
# 2              Carbohydrate, by difference  Composition        g     3.060
# 3                                      Ash        Other        g     3.280
# 4                                   Energy       Energy     kcal   376.000
# 5                                    Water  Composition        g    39.280
# 6                                   Energy       Energy       kJ  1573.000
# 7                     Fiber, total dietary  Composition        g     0.000
# 8                              Calcium, Ca     Elements       mg   673.000
# 9                                 Iron, Fe     Elements       mg     0.640
# 10                           Magnesium, Mg     Elements       mg    22.000
# ...

# %% [markdown]
# #### 열 제목 변경

# %%
col_mapping = {'description': 'food',
              'group': 'fgroup'}

# index를 사용해도 변경가능하나, 바꾸고자 하는 컬럼이 많은경우 순서맞추기가 어렵다
info = info.rename(columns=col_mapping, copy=False) # copy=False, 원본에서 조작하고 복사본을 만들지 말라라는 의미?
info
# Out:
#                                                    food  \
# 0                                       Cheese, caraway
# 1                                       Cheese, cheddar
# 2                                          Cheese, edam
# 3                                          Cheese, feta
# 4                    Cheese, mozzarella, part skim milk
# 5      Cheese, mozzarella, part skim milk, low moisture
# 6                                        Cheese, romano
# 7                                     Cheese, roquefort
# 8     Cheese spread, pasteurized process, american, ...
# 9                           Cream, fluid, half and half
# 10    Sour dressing, non-butterfat, cultured, filled...
# 11    Milk, filled, fluid, with blend of hydrogenate...
# 12    Cream substitute, liquid, with lauric acid oil...
# 13                           Cream substitute, powdered
# 14                  Milk, producer, fluid, 3.7% milkfat
# 15    Milk, reduced fat, fluid, 2% milkfat, with add...
# ...

# %%
ndata = pd.merge(nutrients, info, on='id', how='outer')

# %%
ndata
# Out:
#                                description        group    units     value  \
# 0                                  Protein  Composition        g    25.180
# 1                        Total lipid (fat)  Composition        g    29.200
# 2              Carbohydrate, by difference  Composition        g     3.060
# 3                                      Ash        Other        g     3.280
# 4                                   Energy       Energy     kcal   376.000
# 5                                    Water  Composition        g    39.280
# 6                                   Energy       Energy       kJ  1573.000
# 7                     Fiber, total dietary  Composition        g     0.000
# 8                              Calcium, Ca     Elements       mg   673.000
# 9                                 Iron, Fe     Elements       mg     0.640
# 10                           Magnesium, Mg     Elements       mg    22.000
# ...

# %%
ndata.ix[30000]
# Out:
# description                                    Glycine
# group                                      Amino Acids
# units                                                g
# value                                             0.04
# id                                                6158
# food            Soup, tomato bisque, canned, condensed
# fgroup                      Soups, Sauces, and Gravies
# manufacturer
# Name: 30000, dtype: object

# %% [markdown]
# #### 그래프 생성: 영양소 그룹에 따른 아연 함유량

# %%
# %matplotlib inline

# %%
result = ndata.groupby(['description', 'fgroup'])['value'].\
    quantile(0.5)
result['Zinc, Zn'].order().plot(kind='barh')
